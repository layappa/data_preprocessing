# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"R:\aiml\ml\loan_dataset.csv")

# %%
dataset.head(3)
# Out:
#   Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0  LN0001          17795.0             4000.0       300.0             360.0
# 1  LN0002           2860.0                0.0       100.0               NaN
# 2  LN0003           7390.0                NaN       150.0             180.0
#
#    Credit_History Gender Married Dependents     Education Self_Employed  \
# 0             0.0   Male     Yes          2  Not Graduate           NaN
# 1             NaN    NaN     NaN          0  Not Graduate            No
# 2             NaN   Male     NaN          1      Graduate           Yes
#
#   Property_Area Loan_Status
# 0     Semiurban           N
# 1     Semiurban           N
# 2         Rural           Y

# %%
dataset.shape
# Out:
# (21, 13)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# ApplicantIncome       0
# CoapplicantIncome     7
# LoanAmount            2
# Loan_Amount_Term      5
# Credit_History        5
# Gender               10
# Married              11
# Dependents            7
# Education             0
# Self_Employed         7
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Loan_ID               0.000000
# ApplicantIncome       0.000000
# CoapplicantIncome    33.333333
# LoanAmount            9.523810
# Loan_Amount_Term     23.809524
# Credit_History       23.809524
# Gender               47.619048
# Married              52.380952
# Dependents           33.333333
# Education             0.000000
# Self_Employed        33.333333
# Property_Area         0.000000
# Loan_Status           0.000000
# dtype: float64

# %%
(dataset.isnull().sum().sum())/(dataset.shape[0]*dataset.shape[1])*100
# Out:
# 19.78021978021978
